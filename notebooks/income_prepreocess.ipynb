# %%
import pandas as pd


df=pd.read_excel("../data/raw/income.xlsx","Table 1.5")

# %%
# find the labels for the columns
col=df.iloc[6,:]
col=list(col)
col
# Out:
# ['SA2',
#  'SA2 NAME',
#  '2014-15',
#  '2015-16',
#  '2016-17',
#  '2017-18',
#  '2018-19',
#  '2014-15',
#  '2015-16',
#  '2016-17',
#  '2017-18',
#  '2018-19',
#  '2014-15',
#  '2015-16',
#  '2016-17',
#  '2017-18',
#  '2018-19',
#  '2014-15',
#  '2015-16',
#  '2016-17',
#  '2017-18',
#  '2018-19',
#  '2014-15',
#  '2015-16',
#  '2016-17',
#  '2017-18',
#  '2018-19',
#  '2014-15',
#  '2015-16',
#  '2016-17',
#  '2017-18',
#  '2018-19']

# %%
# finalize column names 
col[12]=col[12]+" #jobs*000"
col[13]=col[13]+" #jobs*000"
col[14]=col[14]+" #jobs*000"
col[15]=col[15]+" #jobs*000"
col[16]=col[16]+" #jobs*000"

col[-5]=col[-5]+" MEDIAN EMPLOYMENT INCOME PER JOB"
col[-4]=col[-4]+" MEDIAN EMPLOYMENT INCOME PER JOB"
col[-3]=col[-3]+" MEDIAN EMPLOYMENT INCOME PER JOB"
col[-2]=col[-2]+" MEDIAN EMPLOYMENT INCOME PER JOB"
col[-1]=col[-1]+" MEDIAN EMPLOYMENT INCOME PER JOB"

# %%
col
# Out:
# ['SA2',
#  'SA2 NAME',
#  '2014-15',
#  '2015-16',
#  '2016-17',
#  '2017-18',
#  '2018-19',
#  '2014-15',
#  '2015-16',
#  '2016-17',
#  '2017-18',
#  '2018-19',
#  '2014-15 #jobs*000',
#  '2015-16 #jobs*000',
#  '2016-17 #jobs*000',
#  '2017-18 #jobs*000',
#  '2018-19 #jobs*000',
#  '2014-15',
#  '2015-16',
#  '2016-17',
#  '2017-18',
#  '2018-19',
#  '2014-15',
#  '2015-16',
#  '2016-17',
#  '2017-18',
#  '2018-19',
#  '2014-15 MEDIAN EMPLOYMENT INCOME PER JOB',
#  '2015-16 MEDIAN EMPLOYMENT INCOME PER JOB',
#  '2016-17 MEDIAN EMPLOYMENT INCOME PER JOB',
#  '2017-18 MEDIAN EMPLOYMENT INCOME PER JOB',
#  '2018-19 MEDIAN EMPLOYMENT INCOME PER JOB']

# %%
#check labels of different columns
df1=df.iloc[8:,:]

# %%
origName=df1.columns
origName
# Out:
# Index(['            Australian Bureau of Statistics', 'Unnamed: 1',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31'],
#       dtype='object')

# %%
# create dictionary with original column names and actual column names
res = {}
for key in origName:
    for value in col:
        res[key] = value
        col.remove(value)
        break  

res
# Out:
# {'            Australian Bureau of Statistics': 'SA2',
#  'Unnamed: 1': 'SA2 NAME',
#  'Unnamed: 2': '2014-15',
#  'Unnamed: 3': '2015-16',
#  'Unnamed: 4': '2016-17',
#  'Unnamed: 5': '2017-18',
#  'Unnamed: 6': '2018-19',
#  'Unnamed: 7': '2014-15',
#  'Unnamed: 8': '2015-16',
#  'Unnamed: 9': '2016-17',
#  'Unnamed: 10': '2017-18',
#  'Unnamed: 11': '2018-19',
#  'Unnamed: 12': '2014-15 #jobs*000',
#  'Unnamed: 13': '2015-16 #jobs*000',
#  'Unnamed: 14': '2016-17 #jobs*000',
#  'Unnamed: 15': '2017-18 #jobs*000',
#  'Unnamed: 16': '2018-19 #jobs*000',
#  'Unnamed: 17': '2014-15',
#  'Unnamed: 18': '2015-16',
#  'Unnamed: 19': '2016-17',
#  'Unnamed: 20': '2017-18',
#  'Unnamed: 21': '2018-19',
#  'Unnamed: 22': '2014-15',
#  'Unnamed: 23': '2015-16',
#  'Unnamed: 24': '2016-17',
#  'Unnamed: 25': '2017-18',
#  'Unnamed: 26': '2018-19',
#  'Unnamed: 27': '2014-15 MEDIAN EMPLOYMENT INCOME PER JOB',
#  'Unnamed: 28': '2015-16 MEDIAN EMPLOYMENT INCOME PER JOB',
# ...

# %%
# change the column names of the dataframe
df1=df1.rename(columns=res)
df1
# Out:
#                                                     SA2           SA2 NAME  \
# 8                                       New South Wales                NaN
# 9                                             101021007          Braidwood
# 10                                            101021008            Karabar
# 11                                            101021009         Queanbeyan
# 12                                            101021010  Queanbeyan - East
# ...                                                 ...                ...
# 2302                                          801111140   ACT - South West
# 2303                                          801111141            Namadgi
# 2304                                                NaN                NaN
# 2305  (a) Totals are higher than the sum of their co...                NaN
# 2306  np - not published to protect the confidential...                NaN
#
# ...

# %%
df1.loc[585]
# Out:
# SA2                                         Victoria
# SA2 NAME                                         NaN
# 2014-15                                      2348.18
# 2015-16                                      2388.69
# 2016-17                                      2500.57
# 2017-18                                       2582.7
# 2018-19                                      2664.61
# 2014-15                                      2222.37
# 2015-16                                      2263.54
# 2016-17                                      2363.68
# 2017-18                                      2432.57
# 2018-19                                      2555.26
# 2014-15 #jobs*000                            4570.54
# 2015-16 #jobs*000                            4652.23
# 2016-17 #jobs*000                            4864.25
# 2017-18 #jobs*000                            5015.31
# 2018-19 #jobs*000                            5219.87
# 2014-15                                        29615
# ...

# %%
df1.loc[1047]
# Out:
# SA2                                                   217041480
# SA2 NAME                                    Warrnambool - South
# 2014-15                                                   5.385
# 2015-16                                                   5.301
# 2016-17                                                   5.378
# 2017-18                                                   5.265
# 2018-19                                                   5.731
# 2014-15                                                   5.141
# 2015-16                                                   5.338
# 2016-17                                                    5.37
# 2017-18                                                   5.178
# 2018-19                                                   5.921
# 2014-15 #jobs*000                                        10.524
# 2015-16 #jobs*000                                        10.644
# 2016-17 #jobs*000                                        10.748
# ...

# %%
# filter out datas thats in victoria

df1=df1.loc[586:1047,:]
df1
# Out:
#             SA2             SA2 NAME 2014-15 2015-16 2016-17 2017-18 2018-19  \
# 586   201011001            Alfredton   4.197   4.389   4.818   5.027    5.43
# 587   201011002             Ballarat   4.734   4.694   4.808   4.789   4.917
# 588   201011003     Ballarat - North    8.52   8.513   8.735   8.981   9.135
# 589   201011004     Ballarat - South   7.895   8.011   8.382   8.635   9.044
# 590   201011005            Buninyong   2.643   2.614   2.643   2.767   2.814
# ...         ...                  ...     ...     ...     ...     ...     ...
# 1043  217031476                Otway    1.51   1.533   1.598   1.566   1.623
# 1044  217041477         Moyne - East   3.144   3.005   3.137   3.208   3.389
# 1045  217041478         Moyne - West   4.114   4.013   3.997   4.034   4.171
# 1046  217041479  Warrnambool - North   8.755   8.793   9.066   9.042    9.57
# 1047  217041480  Warrnambool - South   5.385   5.301   5.378   5.265   5.731
#
# ...

# %%
df1=df1.drop(["2014-15","2015-16","2016-17","2017-18","2018-19"],axis=1)
df1
# Out:
#             SA2             SA2 NAME 2014-15 #jobs*000 2015-16 #jobs*000  \
# 586   201011001            Alfredton             8.545             9.019
# 587   201011002             Ballarat              9.81             9.789
# 588   201011003     Ballarat - North            17.066            17.145
# 589   201011004     Ballarat - South            15.975            16.114
# 590   201011005            Buninyong              5.31              5.19
# ...         ...                  ...               ...               ...
# 1043  217031476                Otway             3.151             3.063
# 1044  217041477         Moyne - East             5.913             5.766
# 1045  217041478         Moyne - West              8.01             7.845
# 1046  217041479  Warrnambool - North            17.351            17.375
# 1047  217041480  Warrnambool - South            10.524            10.644
#
#      2016-17 #jobs*000 2017-18 #jobs*000 2018-19 #jobs*000  \
# ...

# %%
df1.to_csv('../data/curated/income.csv',index=False)

# %%
df= pd.read_csv('../data/curated/income.csv')
df
# Out:
#            SA2             SA2 NAME 2014-15 #jobs*000 2015-16 #jobs*000  \
# 0    201011001            Alfredton             8.545             9.019
# 1    201011002             Ballarat              9.81             9.789
# 2    201011003     Ballarat - North            17.066            17.145
# 3    201011004     Ballarat - South            15.975            16.114
# 4    201011005            Buninyong              5.31              5.19
# ..         ...                  ...               ...               ...
# 457  217031476                Otway             3.151             3.063
# 458  217041477         Moyne - East             5.913             5.766
# 459  217041478         Moyne - West              8.01             7.845
# 460  217041479  Warrnambool - North            17.351            17.375
# 461  217041480  Warrnambool - South            10.524            10.644
#
#     2016-17 #jobs*000 2017-18 #jobs*000 2018-19 #jobs*000  \
# ...
