# %% [markdown]
# This file extracts data that is needed from the population dataset which is in excel form, filter out unuseful rows and columns, set column names, and convert and save the file into csv format

# %%
import pandas as pd


df=pd.read_excel("../data/raw/population.xlsx","Table 1")

# %%
# find the labels for the columns
areaName=df.iloc[6,:10]
populationYear=df.iloc[5,10:]
col=areaName.append(populationYear)
# Out:
# /tmp/ipykernel_9801/1809354427.py:4: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   col=areaName.append(populationYear)

# %%
col=list(col)
col
# Out:
# ['S/T code',
#  'S/T name',
#  'GCCSA code',
#  'GCCSA name',
#  'SA4 code',
#  'SA4 name',
#  'SA3 code',
#  'SA3 name',
#  'SA2 code',
#  'SA2 name',
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021,
#  nan,
#  '2011-2021',
#  nan,
#  nan,
#  'Area',
#  'Population density 2021']

# %%
# remove column names for two columns that dont have any values
col.pop(31)
# Out:
# nan

# %%
col.pop(33)
# Out:
# nan

# %%
col
# Out:
# ['S/T code',
#  'S/T name',
#  'GCCSA code',
#  'GCCSA name',
#  'SA4 code',
#  'SA4 name',
#  'SA3 code',
#  'SA3 name',
#  'SA2 code',
#  'SA2 name',
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021,
#  '2011-2021',
#  nan,
#  'Area',
#  'Population density 2021']

# %%
# finalize column names 
col[31]=col[31]+"no"

# %%
col[32]="2011-2021%"

# %%
col
# Out:
# ['S/T code',
#  'S/T name',
#  'GCCSA code',
#  'GCCSA name',
#  'SA4 code',
#  'SA4 name',
#  'SA3 code',
#  'SA3 name',
#  'SA2 code',
#  'SA2 name',
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021,
#  '2011-2021no',
#  '2011-2021%',
#  'Area',
#  'Population density 2021']

# %%
#check labels of different columns
df.iloc[5:,:]
# Out:
#                  Australian Bureau of Statistics       Unnamed: 1  Unnamed: 2  \
# 5                                            NaN              NaN         NaN
# 6                                       S/T code         S/T name  GCCSA code
# 7                                            NaN              NaN         NaN
# 8                                              1  New South Wales       1RNSW
# 9                                              1  New South Wales       1RNSW
# ...                                          ...              ...         ...
# 2464                                         NaN              NaN         NaN
# 2465                                         NaN              NaN         NaN
# 2466           Source: Regional population, 2021              NaN         NaN
# 2467                                         NaN              NaN         NaN
# 2468            © Commonwealth of Australia 2022              NaN         NaN
#
# ...

# %%
# filter out the values, the values begin from row 8
df1=df.iloc[8:,:]
df1
# Out:
#                  Australian Bureau of Statistics       Unnamed: 1 Unnamed: 2  \
# 8                                              1  New South Wales      1RNSW
# 9                                              1  New South Wales      1RNSW
# 10                                             1  New South Wales      1RNSW
# 11                                             1  New South Wales      1RNSW
# 12                                             1  New South Wales      1RNSW
# ...                                          ...              ...        ...
# 2464                                         NaN              NaN        NaN
# 2465                                         NaN              NaN        NaN
# 2466           Source: Regional population, 2021              NaN        NaN
# 2467                                         NaN              NaN        NaN
# 2468            © Commonwealth of Australia 2022              NaN        NaN
#
# ...

# %%
# remove columns with no data
df1=df1.drop(["Unnamed: 31","Unnamed: 34"],axis=1)

# %%
origName=df1.columns
origName
# Out:
# Index(['            Australian Bureau of Statistics', 'Unnamed: 1',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 35', 'Unnamed: 36'],
#       dtype='object')

# %%
# create dictionary with original column names and actual column names
res = {}
for key in origName:
    for value in col:
        res[key] = value
        col.remove(value)
        break  

res
# Out:
# {'            Australian Bureau of Statistics': 'S/T code',
#  'Unnamed: 1': 'S/T name',
#  'Unnamed: 2': 'GCCSA code',
#  'Unnamed: 3': 'GCCSA name',
#  'Unnamed: 4': 'SA4 code',
#  'Unnamed: 5': 'SA4 name',
#  'Unnamed: 6': 'SA3 code',
#  'Unnamed: 7': 'SA3 name',
#  'Unnamed: 8': 'SA2 code',
#  'Unnamed: 9': 'SA2 name',
#  'Unnamed: 10': 2001,
#  'Unnamed: 11': 2002,
#  'Unnamed: 12': 2003,
#  'Unnamed: 13': 2004,
#  'Unnamed: 14': 2005,
#  'Unnamed: 15': 2006,
#  'Unnamed: 16': 2007,
#  'Unnamed: 17': 2008,
#  'Unnamed: 18': 2009,
#  'Unnamed: 19': 2010,
#  'Unnamed: 20': 2011,
#  'Unnamed: 21': 2012,
#  'Unnamed: 22': 2013,
#  'Unnamed: 23': 2014,
#  'Unnamed: 24': 2015,
#  'Unnamed: 25': 2016,
#  'Unnamed: 26': 2017,
#  'Unnamed: 27': 2018,
#  'Unnamed: 28': 2019,
#  'Unnamed: 29': 2020,
#  'Unnamed: 30': 2021,
#  'Unnamed: 32': '2011-2021no',
#  'Unnamed: 33': '2011-2021%',
#  'Unnamed: 35': 'Area',
#  'Unnamed: 36': 'Population density 2021'}

# %%
# change the column names of the dataframe
df1=df1.rename(columns=res)
df1
# Out:
#                                S/T code         S/T name GCCSA code  \
# 8                                     1  New South Wales      1RNSW
# 9                                     1  New South Wales      1RNSW
# 10                                    1  New South Wales      1RNSW
# 11                                    1  New South Wales      1RNSW
# 12                                    1  New South Wales      1RNSW
# ...                                 ...              ...        ...
# 2464                                NaN              NaN        NaN
# 2465                                NaN              NaN        NaN
# 2466  Source: Regional population, 2021              NaN        NaN
# 2467                                NaN              NaN        NaN
# 2468   © Commonwealth of Australia 2022              NaN        NaN
#
#        GCCSA name SA4 code        SA4 name SA3 code    SA3 name   SA2 code  \
# ...

# %%
# filter out datas thats in victoria

df1=df1.loc[df1["S/T code"]==2]
df1
# Out:
#      S/T code  S/T name GCCSA code    GCCSA name SA4 code  \
# 650         2  Victoria      2RVIC  Rest of Vic.      201
# 651         2  Victoria      2RVIC  Rest of Vic.      201
# 652         2  Victoria      2RVIC  Rest of Vic.      201
# 653         2  Victoria      2RVIC  Rest of Vic.      201
# 654         2  Victoria      2RVIC  Rest of Vic.      201
# ...       ...       ...        ...           ...      ...
# 1167        2  Victoria      2RVIC  Rest of Vic.      217
# 1168        2  Victoria      2RVIC  Rest of Vic.      217
# 1169        2  Victoria      2RVIC  Rest of Vic.      217
# 1170        2  Victoria      2RVIC  Rest of Vic.      217
# 1171        2  Victoria      2RVIC  Rest of Vic.      217
#
#                         SA4 name SA3 code             SA3 name   SA2 code  \
# 650                     Ballarat    20101             Ballarat  201011001
# 651                     Ballarat    20101             Ballarat  201011002
# ...

# %%
df1=df1.iloc[:,8:]

# %%
df1.to_csv('../data/curated/population.csv',index=False)

# %%
df= pd.read_csv('../data/curated/population.csv')
df
# Out:
#       SA2 code             SA2 name   2001   2002   2003   2004   2005   2006  \
# 0    201011001            Alfredton   5756   6092   6293   6480   6648   6761
# 1    201011002             Ballarat  11497  11708  12015  12189  12269  12356
# 2    201011005            Buninyong   5320   5399   5557   5620   5857   6037
# 3    201011006            Delacombe   4154   4225   4371   4465   4704   5041
# 4    201011007        Smythes Creek   3317   3378   3411   3473   3508   3542
# ..         ...                  ...    ...    ...    ...    ...    ...    ...
# 517  217031476                Otway   3452   3479   3511   3511   3492   3459
# 518  217041477         Moyne - East   6718   6704   6676   6643   6638   6652
# 519  217041478         Moyne - West   8317   8387   8450   8487   8517   8601
# 520  217041479  Warrnambool - North  17053  17449  17726  17937  18172  18528
# 521  217041480  Warrnambool - South  12506  12578  12639  12697  12748  12792
#
# ...
