# %% [markdown]
# This file will do some basic analysing and population forecasting based on the SA2 for different locations

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('../data/curated/population.csv')
df
# Out:
#       SA2 code             SA2 name   2001   2002   2003   2004   2005   2006  \
# 0    201011001            Alfredton   5756   6092   6293   6480   6648   6761
# 1    201011002             Ballarat  11497  11708  12015  12189  12269  12356
# 2    201011005            Buninyong   5320   5399   5557   5620   5857   6037
# 3    201011006            Delacombe   4154   4225   4371   4465   4704   5041
# 4    201011007        Smythes Creek   3317   3378   3411   3473   3508   3542
# ..         ...                  ...    ...    ...    ...    ...    ...    ...
# 517  217031476                Otway   3452   3479   3511   3511   3492   3459
# 518  217041477         Moyne - East   6718   6704   6676   6643   6638   6652
# 519  217041478         Moyne - West   8317   8387   8450   8487   8517   8601
# 520  217041479  Warrnambool - North  17053  17449  17726  17937  18172  18528
# 521  217041480  Warrnambool - South  12506  12578  12639  12697  12748  12792
#
# ...

# %%
plt.boxplot(df["2021"])
plt.title("2021 population")
# Out:
# Text(0.5, 1.0, '2021 population')

# %%
plt.boxplot(df["2011-2021no"])
plt.title("number of population increase from 2011 to 2021")
# Out:
# Text(0.5, 1.0, 'number of population increase from 2011 to 2021')

# %%
plt.boxplot(df["2011-2021%"])
plt.title("percentage of population increase from 2011 to 2021")
# Out:
# Text(0.5, 1.0, 'percentage of population increase from 2011 to 2021')

# %%
plt.boxplot(df["Population density 2021"])
plt.title("Population density 2021")
# Out:
# Text(0.5, 1.0, 'Population density 2021')

# %%
plt.boxplot(df.iloc[:,2:23])
plt.title("distribution of population from 2001 to 2021")
# Out:
# Text(0.5, 1.0, 'distribution of population from 2001 to 2021')

# %%
population= df.iloc[:,2:23]
sample=population.sample(n=20,random_state=114514)
x=list(sample.columns)
sample
# Out:
#       2001   2002   2003   2004   2005   2006   2007   2008   2009   2010  \
# 367     13     24     41     55     75     98    314    707   1330   2213
# 364     12     15     19     32     50     69     73     66     75     82
# 452    478    713   1016   1380   1729   2057   2809   3786   5073   6608
# 22    8823   8925   9029   9103   9132   9173   9184   9212   9268   9310
# 490   3709   3778   3815   3809   3818   3837   3776   3724   3689   3671
# 5    13355  13255  13161  13095  13028  12963  13033  13334  13718  14104
# 440     38     38     35     40     68    300    853   1579   2487   4182
# 416   5972   6571   7244   7624   8026   8550   9204   9736  10125  10510
# 70   17109  17123  17136  17175  17223  17320  17419  17541  17676  17837
# 59    6188   6164   6139   6102   6047   6019   6040   6035   6015   6017
# 45    9774   9769   9787   9800   9807   9827   9857   9885   9913   9968
# 125  13659  13645  13650  13673  13776  13908  14043  14215  14416  14617
# ...

# %%
for i in range(len(sample)):
    plt.scatter(x,sample.iloc[i])

# %%
population= df.iloc[:,2:23]
sample=population.sample(n=20,random_state=1919810)
x=list(sample.columns)
sample
# Out:
#       2001   2002   2003   2004   2005   2006   2007   2008   2009   2010  \
# 458  17131  17187  17296  17394  17519  17722  17823  17928  18084  18176
# 61    6907   6982   7037   7158   7408   7601   7707   7865   8026   8144
# 22    8823   8925   9029   9103   9132   9173   9184   9212   9268   9310
# 316   9519   9515   9497   9504   9530   9541   9569   9599   9637   9660
# 65     173    176    177    179    184    187    194    202    213    219
# 446     74     73    109    151    204    307    326    379    356    318
# 157   8433   8450   8457   8484   8525   8586   8692   8747   8761   8801
# 493  12544  12806  13167  13244  13651  13848  13961  14085  14175  14278
# 440     38     38     35     40     68    300    853   1579   2487   4182
# 186   9807   9841   9856   9957  10048  10227  10363  10650  10936  11150
# 14    3151   3163   3182   3202   3247   3294   3296   3293   3333   3343
# 383    698    748    868   1091   1706   2397   3240   4088   4690   4684
# ...

# %%
for i in range(len(sample)):
    plt.scatter(x,sample.iloc[i])
